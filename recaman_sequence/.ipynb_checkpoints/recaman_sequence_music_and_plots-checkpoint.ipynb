# %%
import abjad
# Out:
# NOTE: The Pärt demo requires abjad-ext-tonality

# %%
# %load_ext abjadext.ipython

# %% [markdown]
# Test out abjad for notes visualisation.

# %% [markdown]
# # Recaman Sequence
#
# Let us generate the recaman sequence.

# %%
def recaman(n):
    """Produce n first elements of the recaman sequence."""
    seq = [0]
    for step in range(1, n):
        last = seq[-1]
        if (last-step > 1) and (last-step not in seq):
            seq.append(last-step)
        else:
            seq.append(last+step)
    return seq

# %%
recaman(10)
# Out:
# [0, 1, 3, 6, 2, 7, 13, 20, 12, 21]

# %% [markdown]
# And convert it to the notes:

# %%
def int_seq_to_notes(seq, duration=abjad.Duration(1, 16), offset=0):
    notes = []
    for x in seq:
        notes.append(abjad.Note(x+offset, duration))
    return abjad.Container(notes)

# %%
container = int_seq_to_notes(recaman(50), offset=0)

# %%
abjad.show(container)
# Out:
# ----------------------------------------------------------------
# RuntimeError                   Traceback (most recent call last)
# <ipython-input-13-0b33efc7e3f8> in <module>
# ----> 1 abjad.show(container)
#
# ~/.local/lib/python3.7/site-packages/abjadext/ipython/Show.py in __call__(self, argument)
#      27             pngs = []
#      28             if not success:
# ---> 29                 raise RuntimeError('Rendering failed')
#      30             if not png_paths:
#      31                 raise FileNotFoundError('LilyPond PNG output not found.')
#
# RuntimeError: Rendering failed

# %%
abjad.play(container)
# Out:
# <audio controls type="audio/ogg" src="data:audio/ogg;base64,...">

# %% [markdown]
# ## Plotting
#
# I also want to try to plot the connections between the consequitive numbers as semi circles (fitting for the pattern of integers).

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as ptch
# %matplotlib notebook

# %%
def arc_between_numbers(x1, x2, is_above):
    thetas = (0, 180) if is_above else (180, 360)
    center = ((x1+x2)/2, 0)
    d = abs(x1-x2)
    return ptch.Arc(xy=center, width=d, height=d, theta1=thetas[0], theta2=thetas[1])

# %%
def show_sequence(seq):
    fig = plt.figure()
    ax = fig.add_subplot()
    
    ax.set_xlim(0, max(seq))
    ax.set_ylim(-max(seq)/3.5, max(seq)/3.5)
    
    is_above = True
    for i in range(len(seq)-1):
        x1 = seq[i]
        x2 = seq[i+1]
        arc = arc_between_numbers(x1, x2, is_above)
        is_above = not is_above
        ax.add_patch(arc)

    plt.show()

# %%
show_sequence(recaman(100))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Natural numbers
show_sequence(list(range(50)))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import random

# %%
# Random permutation
seq = list(range(100))
random.shuffle(seq)
show_sequence(seq)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# The radius of circles is actually showing the change.
